# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df = pd.read_csv('dataset/Crop_recommendation.csv')
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label  Unnamed: 8  Unnamed: 9
# 0     202.935536    rice         NaN         NaN
# 1     226.655537    rice         NaN         NaN
# 2     263.964248    rice         NaN         NaN
# 3     242.864034    rice         NaN         NaN
# 4     262.717340    rice         NaN         NaN
# ...          ...     ...         ...         ...
# 2195  177.774507  coffee         NaN         NaN
# 2196  127.924610  coffee         NaN         NaN
# 2197  173.322839  coffee         NaN         NaN
# 2198  127.175293  coffee         NaN         NaN
# 2199  140.937041  coffee         NaN         NaN
#
# [2200 rows x 10 columns]

# %%
df.shape
# Out:
# (2200, 10)

# %%
df.isnull().sum()
# Out:
# Nitrogen          0
# phosphorus        0
# potassium         0
# temperature       0
# humidity          0
# ph                0
# rainfall          0
# label             0
# Unnamed: 8     2200
# Unnamed: 9     2200
# dtype: int64

# %%
df = df.drop(['Unnamed: 8','Unnamed: 9' ], axis='columns')
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# 2     263.964248    rice
# 3     242.864034    rice
# 4     262.717340    rice
# ...          ...     ...
# 2195  177.774507  coffee
# 2196  127.924610  coffee
# 2197  173.322839  coffee
# 2198  127.175293  coffee
# 2199  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df['crop'] = df['label']
df=df.drop('label', axis=1)
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall    crop
# 0     202.935536    rice
# 1     226.655537    rice
# 2     263.964248    rice
# 3     242.864034    rice
# 4     262.717340    rice
# ...          ...     ...
# 2195  177.774507  coffee
# 2196  127.924610  coffee
# 2197  173.322839  coffee
# 2198  127.175293  coffee
# 2199  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# Finding unique values

# %%
for column in df.columns:
    unique = df[column].unique()
    print(f"Unique values in column '{column}': {unique}")
    print()
# Out:
# Unique values in column 'Nitrogen': [ 90  85  60  74  78  69  94  89  68  91  93  77  88  76  67  83  98  66
#   97  84  73  92  95  99  63  62  64  82  79  65  75  71  72  70  86  61
#   81  80 100  87  96  40  23  39  22  36  32  58  59  42  28  43  27  50
#   25  31  26  54  57  49  46  38  35  52  44  24  29  20  56  37  51  41
#   34  30  33  47  53  45  48  13   2  17  12   6  10  19  11  18  21  16
#    9   1   7   8   0   3   4   5  14  15  55 105 108 118 101 106 109 117
#  114 110 112 111 102 116 119 107 104 103 120 113 115 133 136 126 121 129
#  122 140 131 135 123 125 139 132 127 130 134]
#
# Unique values in column 'phosphorus': [ 42  58  55  35  37  53  54  46  56  50  48  38  45  40  59  41  47  49
#   51  57  39  43  44  60  52  36  72  67  73  70  62  74  66  63  71  78
#   80  68  65  77  76  79  61  64  69  75  24  18  26  27  25  21  30  11
#    5  10   7  20  22  15  23   8  16  29  17   6  19  13   9  14  28  94
#   95  92  89  88  87  85  86  83  91  81  84  90  82  93  33  31  34  32
#  130 144 123 125 131 140 122 134 145 139 141 138 136 132 133 121 126 120
#  142 135 129 128 137 127 124 143  12]
#
# Unique values in column 'potassium': [ 43  41  44  40  42  38  36  37  39  35  45  16  17  21  20  19  25  22
#   15  18  23  24  77  84  85  81  75  79  76  83  78  80  82  46  50  53
#   54  49  55  52  47  48  51  27  31  32  34  33  30  28  29  26 195 204
#  205 196 198 197 203 201 202 199 200  12  13   6   9  10  14   8   7   5
#   11]
#
# Unique values in column 'temperature': [20.87974371 21.77046169 23.00445915 ... 24.13179691 26.2724184
#  23.60301571]
#
# Unique values in column 'humidity': [82.00274423 80.31964408 82.3207629  ... 67.22512329 52.12739421
#  60.39647474]
#
# Unique values in column 'ph': [6.50298529 7.03809636 7.84020714 ... 6.36260785 6.75879255 6.77983261]
#
# Unique values in column 'rainfall': [202.9355362 226.6555374 263.9642476 ... 173.3228386 127.1752928
#  140.9370415]
#
# Unique values in column 'crop': ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']

# %%
# cheking tempreture is in correct format

# %%
isvalid = True

if np.isnan(df['temperature']).any() or np.isinf(df['temperature']).any():
    print("Dataset contains NaN or Inf values. Please handle them.")
    isvalid=False

# Check for non-numeric values
if not np.issubdtype(df['temperature'].dtype, np.number):
    print("Dataset contains non-numeric values. Please ensure all data are numbers.")
    isvalid=False

# Check for correct format
# For example, if you expect all data to be in float format, you can check that
if df['temperature'].dtype != np.float64:
    print("Dataset format is incorrect. Please ensure all data are in the correct format.")
    isvalid=False

if isvalid:
    print('Tempreture all fomart corret')
# Out:
# Tempreture all fomart corret

# %%
df.describe()
# Out:
#           Nitrogen   phosphorus    potassium  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.crop.value_counts()
# Out:
# crop
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %% [markdown]
# Outlier handdling

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Nitrogen

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['Nitrogen'])
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['phosphorus'])
plt.show()

# %%
plt.hist(df['phosphorus'], bins=25, rwidth=0.8)
plt.xlabel('Phosphorus')
plt.ylabel('Count')
plt.show()

# %%
from scipy.stats import norm
import numpy as np

plt.hist(df['phosphorus'], bins=20, rwidth=0.8, density=True)
plt.xlabel('Capital Loss')
plt.ylabel('Count')

rng = np.arange(df['phosphorus'].min(), df['phosphorus'].max(), 0.1)
plt.plot(rng, norm.pdf(rng, df['phosphorus'].mean(), df['phosphorus'].std()))

# %%
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall    crop
# 0     202.935536    rice
# 1     226.655537    rice
# 2     263.964248    rice
# 3     242.864034    rice
# 4     262.717340    rice
# ...          ...     ...
# 2195  177.774507  coffee
# 2196  127.924610  coffee
# 2197  173.322839  coffee
# 2198  127.175293  coffee
# 2199  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['potassium'])
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['temperature'])
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['humidity'])
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['ph'])
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df['rainfall'])
plt.show()

# %% [markdown]
# Encoding the data

# %%
df.dtypes
# Out:
# Nitrogen         int64
# phosphorus       int64
# potassium        int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# crop            object
# dtype: object

# %%
crop_list = []
unique_values = df['crop'].unique() 
crop_list.append(unique_values)
print(crop_list)
# Out:
# [array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
# Fit and transform the 'crop' column
df['crop'] = label.fit_transform(df['crop'])

# %%
# Store the mapping of encoded labels to original string values
encoded_mapping = dict(zip(label.transform(label.classes_), label.classes_))
list=[]
# Iterate over the encoded values and print the corresponding original string values
for encoded_value in df['crop']:
    if encoded_value in list:
      continue
    else:    
      original_value = encoded_mapping[encoded_value]
      print(f"{encoded_value},'{original_value}'")
      list.append(encoded_value)
# Out:
# 20,'rice'
# 11,'maize'
# 3,'chickpea'
# 9,'kidneybeans'
# 18,'pigeonpeas'
# 13,'mothbeans'
# 14,'mungbean'
# 2,'blackgram'
# 10,'lentil'
# 19,'pomegranate'
# 1,'banana'
# 12,'mango'
# 7,'grapes'
# 21,'watermelon'
# 15,'muskmelon'
# 0,'apple'
# 16,'orange'
# 17,'papaya'
# 4,'coconut'
# 6,'cotton'
# 8,'jute'
# 5,'coffee'

# %%
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall  crop
# 0     202.935536    20
# 1     226.655537    20
# 2     263.964248    20
# 3     242.864034    20
# 4     262.717340    20
# ...          ...   ...
# 2195  177.774507     5
# 2196  127.924610     5
# 2197  173.322839     5
# 2198  127.175293     5
# 2199  140.937041     5
#
# [2200 rows x 8 columns]

# %%
x = df.drop('crop',axis=1)
y = df['crop']

# %%
x
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall
# 0     202.935536
# 1     226.655537
# 2     263.964248
# 3     242.864034
# 4     262.717340
# ...          ...
# 2195  177.774507
# 2196  127.924610
# 2197  173.322839
# 2198  127.175293
# 2199  140.937041
#
# [2200 rows x 7 columns]

# %%
y
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 2195     5
# 2196     5
# 2197     5
# 2198     5
# 2199     5
# Name: crop, Length: 2200, dtype: int32

# %%
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall  crop
# 0     202.935536    20
# 1     226.655537    20
# 2     263.964248    20
# 3     242.864034    20
# 4     262.717340    20
# ...          ...   ...
# 2195  177.774507     5
# 2196  127.924610     5
# 2197  173.322839     5
# 2198  127.175293     5
# 2199  140.937041     5
#
# [2200 rows x 8 columns]

# %% [markdown]
# Corelation  Metrix

# %%
corr_matrix = df.corr()

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Compute the correlation report
corr_report = df.corr()
corr_report
# Out:
#              Nitrogen  phosphorus  potassium  temperature  humidity        ph  \
# Nitrogen     1.000000   -0.231460  -0.140512     0.026504  0.190688  0.096683
# phosphorus  -0.231460    1.000000   0.736232    -0.127541 -0.118734 -0.138019
# potassium   -0.140512    0.736232   1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504   -0.127541  -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688   -0.118734   0.190859     0.205320  1.000000 -0.008483
# ph           0.096683   -0.138019  -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020   -0.063839  -0.053461    -0.030084  0.094423 -0.109069
# crop        -0.031130   -0.491006  -0.346417     0.113606  0.193911 -0.012253
#
#              rainfall      crop
# Nitrogen     0.059020 -0.031130
# phosphorus  -0.063839 -0.491006
# potassium   -0.053461 -0.346417
# temperature -0.030084  0.113606
# humidity     0.094423  0.193911
# ph          -0.109069 -0.012253
# rainfall     1.000000  0.045611
# crop         0.045611  1.000000

# %% [markdown]
# Train the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
len(X_train),len(X_test)
# Out:
# (1760, 440)

# %%
len(y_train),len(y_test)
# Out:
# (1760, 440)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
lr_pred = lr.predict(X_test)
lr.score(X_train,y_train), lr.score(X_test,y_test)
# Out:
# (0.9818181818181818, 0.9522727272727273)

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
dtf = DecisionTreeClassifier()

# %%
dtf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtf.score(X_train,y_train)
# Out:
# 1.0

# %%
dtf.score(X_test,y_test)
# Out:
# 0.9863636363636363

# %%
dtf_pred  = dtf.predict(X_test)

# %%
# Assuming y_test and y_pred are your true labels and predicted labels, respectively
# If you're using scikit-learn, you can obtain these values directly from your model

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, dtf_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_train,y_train)
# Out:
# 1.0

# %%
rf.score(X_test,y_test)
# Out:
# 0.9931818181818182

# %%
rf_pred  = rf.predict(X_test)

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, rf_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Gradient Boosting (XGBoost)

# %%
from xgboost import XGBClassifier

# %%
# Initialize the XGBoost classifier
xgb = XGBClassifier()

# Train the classifier on the training data
xgb.fit(X_train, y_train)

# Make predictions
xgb_pred = xgb.predict(X_test)

# %%
xgb.score(X_train,y_train)
# Out:
# 1.0

# %%
xgb.score(X_test,y_test)
# Out:
# 0.9863636363636363

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, xgb_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Neural Networks (using TensorFlow/Keras)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Calculate the number of unique classes in the target variable
num_classes = len(set(y_train))

# Initialize the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model on the training data
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)


# Make predictions
y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 1s 4ms/step - loss: 7.2570 - accuracy: 0.1918 - val_loss: 2.6312 - val_accuracy: 0.3665
# Epoch 2/100
# 44/44 [==============================] - 0s 1ms/step - loss: 1.4830 - accuracy: 0.5469 - val_loss: 0.8933 - val_accuracy: 0.7557
# Epoch 3/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.7488 - accuracy: 0.7756 - val_loss: 0.5832 - val_accuracy: 0.8438
# Epoch 4/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.8317 - val_loss: 0.4613 - val_accuracy: 0.8608
# Epoch 5/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8864 - val_loss: 0.3199 - val_accuracy: 0.9148
# Epoch 6/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.9041 - val_loss: 0.2856 - val_accuracy: 0.9205
# Epoch 7/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.2594 - accuracy: 0.9318 - val_loss: 0.2418 - val_accuracy: 0.9290
# Epoch 8/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9354 - val_loss: 0.2150 - val_accuracy: 0.9403
# Epoch 9/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.2079 - accuracy: 0.9382 - val_loss: 0.2166 - val_accuracy: 0.9403
# Epoch 10/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.2002 - accuracy: 0.9439 - val_loss: 0.1993 - val_accuracy: 0.9318
# Epoch 11/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 0.9403 - val_loss: 0.2066 - val_accuracy: 0.9233
# Epoch 12/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1650 - accuracy: 0.9489 - val_loss: 0.1614 - val_accuracy: 0.9460
# Epoch 13/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1533 - accuracy: 0.9588 - val_loss: 0.1475 - val_accuracy: 0.9631
# Epoch 14/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1523 - accuracy: 0.9510 - val_loss: 0.1431 - val_accuracy: 0.9602
# Epoch 15/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1416 - accuracy: 0.9595 - val_loss: 0.1400 - val_accuracy: 0.9574
# Epoch 16/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9581 - val_loss: 0.1745 - val_accuracy: 0.9290
# Epoch 17/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1380 - accuracy: 0.9567 - val_loss: 0.1034 - val_accuracy: 0.9716
# Epoch 18/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9652 - val_loss: 0.1266 - val_accuracy: 0.9659
# Epoch 19/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9595 - val_loss: 0.1029 - val_accuracy: 0.9744
# Epoch 20/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9602 - val_loss: 0.1238 - val_accuracy: 0.9517
# Epoch 21/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1166 - accuracy: 0.9624 - val_loss: 0.1366 - val_accuracy: 0.9517
# Epoch 22/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1218 - accuracy: 0.9609 - val_loss: 0.1005 - val_accuracy: 0.9744
# Epoch 23/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9631 - val_loss: 0.1319 - val_accuracy: 0.9489
# Epoch 24/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1212 - accuracy: 0.9581 - val_loss: 0.1550 - val_accuracy: 0.9432
# Epoch 25/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9482 - val_loss: 0.1059 - val_accuracy: 0.9716
# Epoch 26/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9538 - val_loss: 0.0996 - val_accuracy: 0.9716
# Epoch 27/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.9538 - val_loss: 0.0902 - val_accuracy: 0.9773
# Epoch 28/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1123 - accuracy: 0.9531 - val_loss: 0.1021 - val_accuracy: 0.9716
# Epoch 29/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1191 - accuracy: 0.9581 - val_loss: 0.0998 - val_accuracy: 0.9716
# Epoch 30/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9652 - val_loss: 0.0898 - val_accuracy: 0.9574
# Epoch 31/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9709 - val_loss: 0.0782 - val_accuracy: 0.9773
# Epoch 32/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0882 - accuracy: 0.9695 - val_loss: 0.0882 - val_accuracy: 0.9716
# Epoch 33/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0941 - accuracy: 0.9709 - val_loss: 0.1037 - val_accuracy: 0.9631
# Epoch 34/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0967 - accuracy: 0.9631 - val_loss: 0.1161 - val_accuracy: 0.9517
# Epoch 35/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9702 - val_loss: 0.0856 - val_accuracy: 0.9716
# Epoch 36/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0915 - accuracy: 0.9659 - val_loss: 0.0902 - val_accuracy: 0.9631
# Epoch 37/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9695 - val_loss: 0.0802 - val_accuracy: 0.9716
# Epoch 38/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0867 - accuracy: 0.9680 - val_loss: 0.1056 - val_accuracy: 0.9602
# Epoch 39/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9652 - val_loss: 0.1319 - val_accuracy: 0.9545
# Epoch 40/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0936 - accuracy: 0.9659 - val_loss: 0.0867 - val_accuracy: 0.9688
# Epoch 41/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 0.9645 - val_loss: 0.1148 - val_accuracy: 0.9688
# Epoch 42/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.9638 - val_loss: 0.0948 - val_accuracy: 0.9631
# Epoch 43/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0969 - accuracy: 0.9673 - val_loss: 0.1155 - val_accuracy: 0.9688
# Epoch 44/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9553 - val_loss: 0.0844 - val_accuracy: 0.9716
# Epoch 45/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9659 - val_loss: 0.1336 - val_accuracy: 0.9432
# Epoch 46/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9659 - val_loss: 0.1196 - val_accuracy: 0.9517
# Epoch 47/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9588 - val_loss: 0.1116 - val_accuracy: 0.9574
# Epoch 48/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9602 - val_loss: 0.0761 - val_accuracy: 0.9801
# Epoch 49/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9709 - val_loss: 0.1444 - val_accuracy: 0.9347
# Epoch 50/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0992 - accuracy: 0.9645 - val_loss: 0.0775 - val_accuracy: 0.9744
# Epoch 51/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9709 - val_loss: 0.1602 - val_accuracy: 0.9347
# Epoch 52/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9702 - val_loss: 0.0697 - val_accuracy: 0.9801
# Epoch 53/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0854 - accuracy: 0.9688 - val_loss: 0.0964 - val_accuracy: 0.9602
# Epoch 54/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0869 - accuracy: 0.9645 - val_loss: 0.1953 - val_accuracy: 0.9261
# Epoch 55/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.9666 - val_loss: 0.0792 - val_accuracy: 0.9716
# Epoch 56/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9652 - val_loss: 0.0646 - val_accuracy: 0.9773
# Epoch 57/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0937 - accuracy: 0.9659 - val_loss: 0.1299 - val_accuracy: 0.9460
# Epoch 58/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.9602 - val_loss: 0.0824 - val_accuracy: 0.9744
# Epoch 59/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9688 - val_loss: 0.0642 - val_accuracy: 0.9744
# Epoch 60/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1070 - accuracy: 0.9567 - val_loss: 0.0716 - val_accuracy: 0.9773
# Epoch 61/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0803 - accuracy: 0.9695 - val_loss: 0.0603 - val_accuracy: 0.9830
# Epoch 62/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9616 - val_loss: 0.0906 - val_accuracy: 0.9631
# Epoch 63/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0870 - accuracy: 0.9695 - val_loss: 0.1183 - val_accuracy: 0.9574
# Epoch 64/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9688 - val_loss: 0.0885 - val_accuracy: 0.9631
# Epoch 65/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9723 - val_loss: 0.0791 - val_accuracy: 0.9659
# Epoch 66/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9766 - val_loss: 0.0722 - val_accuracy: 0.9773
# Epoch 67/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0868 - accuracy: 0.9680 - val_loss: 0.0662 - val_accuracy: 0.9659
# Epoch 68/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0897 - accuracy: 0.9616 - val_loss: 0.0714 - val_accuracy: 0.9716
# Epoch 69/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9702 - val_loss: 0.0838 - val_accuracy: 0.9602
# Epoch 70/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0780 - accuracy: 0.9773 - val_loss: 0.0918 - val_accuracy: 0.9574
# Epoch 71/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 0.9744 - val_loss: 0.1060 - val_accuracy: 0.9545
# Epoch 72/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.9709 - val_loss: 0.0854 - val_accuracy: 0.9602
# Epoch 73/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0718 - accuracy: 0.9673 - val_loss: 0.0697 - val_accuracy: 0.9659
# Epoch 74/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9659 - val_loss: 0.1135 - val_accuracy: 0.9574
# Epoch 75/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9695 - val_loss: 0.1047 - val_accuracy: 0.9545
# Epoch 76/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9716 - val_loss: 0.0738 - val_accuracy: 0.9801
# Epoch 77/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9780 - val_loss: 0.0595 - val_accuracy: 0.9801
# Epoch 78/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0897 - accuracy: 0.9652 - val_loss: 0.0687 - val_accuracy: 0.9773
# Epoch 79/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9702 - val_loss: 0.0584 - val_accuracy: 0.9744
# Epoch 80/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.9702 - val_loss: 0.0759 - val_accuracy: 0.9631
# Epoch 81/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.9624 - val_loss: 0.0815 - val_accuracy: 0.9688
# Epoch 82/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9723 - val_loss: 0.0647 - val_accuracy: 0.9631
# Epoch 83/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9751 - val_loss: 0.0609 - val_accuracy: 0.9830
# Epoch 84/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9716 - val_loss: 0.0989 - val_accuracy: 0.9489
# Epoch 85/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0697 - accuracy: 0.9723 - val_loss: 0.0516 - val_accuracy: 0.9830
# Epoch 86/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9773 - val_loss: 0.0606 - val_accuracy: 0.9858
# Epoch 87/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9759 - val_loss: 0.0561 - val_accuracy: 0.9801
# Epoch 88/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0763 - accuracy: 0.9673 - val_loss: 0.0909 - val_accuracy: 0.9688
# Epoch 89/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0781 - accuracy: 0.9680 - val_loss: 0.0653 - val_accuracy: 0.9773
# Epoch 90/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0663 - accuracy: 0.9730 - val_loss: 0.0872 - val_accuracy: 0.9744
# Epoch 91/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9709 - val_loss: 0.0565 - val_accuracy: 0.9801
# Epoch 92/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9759 - val_loss: 0.0612 - val_accuracy: 0.9801
# Epoch 93/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9680 - val_loss: 0.0762 - val_accuracy: 0.9773
# Epoch 94/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9695 - val_loss: 0.0705 - val_accuracy: 0.9773
# Epoch 95/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9751 - val_loss: 0.0696 - val_accuracy: 0.9744
# Epoch 96/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 0.9773 - val_loss: 0.0717 - val_accuracy: 0.9716
# Epoch 97/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 0.9773 - val_loss: 0.0635 - val_accuracy: 0.9830
# Epoch 98/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 0.9773 - val_loss: 0.0658 - val_accuracy: 0.9688
# Epoch 99/100
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0664 - accuracy: 0.9730 - val_loss: 0.0746 - val_accuracy: 0.9631
# Epoch 100/100
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9716 - val_loss: 0.0572 - val_accuracy: 0.9801
# 14/14 [==============================] - 0s 0s/step

# %%
# Evaluate the model on the training data
train_loss, train_accuracy = model.evaluate(X_train, y_train)

print("Training Accuracy:", train_accuracy)
# Out:
# 55/55 [==============================] - 0s 909us/step - loss: 0.0499 - accuracy: 0.9773
# Training Accuracy: 0.9772727489471436

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.95

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# Initialize the SVM classifier
svm = SVC()

# %%
# Train the classifier on the training data
svm.fit(X_train, y_train)

# Make predictions
svm_pred = svm.predict(X_test)

# %%
svm.score(X_train,y_train)
# Out:
# 0.98125

# %%
svm.score(X_test,y_test)
# Out:
# 0.9613636363636363

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, svm_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize the KNN classifier
knn = KNeighborsClassifier()

# %%
# Train the classifier on the training data
knn.fit(X_train, y_train)

# Make predictions
knn_pred = knn.predict(X_test)

# %%
knn.score(X_train,y_train)
# Out:
# 0.9897727272727272

# %%
knn.score(X_test,y_test)
# Out:
# 0.9704545454545455

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, knn_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Ensemble Methods (AdaBoost):

# %%
from sklearn.ensemble import AdaBoostClassifier

# Initialize the AdaBoost classifier
adaboostr = AdaBoostClassifier()

# %%
# Train the classifier on the training data
adaboostr.fit(X_train, y_train)

# Make predictions
adaboostr_pred = adaboostr.predict(X_test)
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
adaboostr.score(X_train,y_train)
# Out:
# 0.14659090909090908

# %%
adaboostr.score(X_test,y_test)
# Out:
# 0.09545454545454546

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, adaboostr_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Techniqeus to reduce the overfiting the random forest model

# %% [markdown]
# Cross validations

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(rf, X_train, y_train, cv=5)

# Print cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean CV score:", cv_scores.mean())
# Out:
# Cross-validation scores: [0.98579545 1.         0.99431818 0.99715909 1.        ]
# Mean CV score: 0.9954545454545454

# %% [markdown]
# Ensemble Methods (e.g., Bagging)

# %%
from sklearn.ensemble import BaggingClassifier

# Initialize the Bagging Classifier with Random Forest as the base estimator
base_rf_classifier = RandomForestClassifier()
bagging_classifier = BaggingClassifier(base_rf_classifier, n_estimators=10)

# Train the Bagging classifier
bagging_classifier.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=RandomForestClassifier())

# %%
bagging_classifier.score(X_train,y_train), bagging_classifier.score(X_test,y_test)
# Out:
# (0.9994318181818181, 0.9931818181818182)

# %% [markdown]
# Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameters to tune
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42), param_grid=param_grid, cv=5)

# Perform grid search
grid_search.fit(X_train, y_train)

# Print best hyperparameters
print("Best hyperparameters:", grid_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %%
grid_search.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.score(X_test,y_test)
# Out:
# 0.9931818181818182

# %%
# Get the best hyperparameters from grid search
best_params = grid_search.best_params_

# Create a new RandomForestClassifier with the best hyperparameters
best_rf_classifier = RandomForestClassifier(**best_params, random_state=42)

# Train the classifier on the entire training dataset
best_rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
best_rf_classifier.score(X_train,y_train)
# Out:
# 1.0

# %%
best_rf_classifier.score(X_test,y_test)
# Out:
# 0.9931818181818182

# %% [markdown]
# Clasification Report

# %%
from sklearn.metrics import classification_report

# %%
print("Decision Tree Classifier:")
print(classification_report(y_test, dtf_pred))
# Out:
# Decision Tree Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       0.95      1.00      0.98        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        14
#            8       0.92      0.96      0.94        23
#            9       1.00      1.00      1.00        20
#           10       0.92      1.00      0.96        11
#           11       1.00      0.95      0.98        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.92      0.96        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       0.93      1.00      0.97        14
#           17       1.00      1.00      1.00        23
#           18       1.00      1.00      1.00        23
#           19       1.00      1.00      1.00        23
#           20       0.94      0.89      0.92        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.99       440
#    macro avg       0.98      0.99      0.99       440
# weighted avg       0.99      0.99      0.99       440

# %%
print("Random Forest Classifier:")
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        14
#            8       0.92      1.00      0.96        23
#            9       1.00      1.00      1.00        20
#           10       0.92      1.00      0.96        11
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.96      0.98        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        14
#           17       1.00      1.00      1.00        23
#           18       1.00      1.00      1.00        23
#           19       1.00      1.00      1.00        23
#           20       1.00      0.89      0.94        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.99       440
#    macro avg       0.99      0.99      0.99       440
# weighted avg       0.99      0.99      0.99       440

# %%
print("Support Vector Machine (SVM) Classifier:")
print(classification_report(y_test, svm_pred))
# Out:
# Support Vector Machine (SVM) Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       0.91      1.00      0.95        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      0.94      0.97        17
#            6       0.85      1.00      0.92        17
#            7       1.00      1.00      1.00        14
#            8       0.77      1.00      0.87        23
#            9       0.95      1.00      0.98        20
#           10       0.79      1.00      0.88        11
#           11       1.00      0.86      0.92        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.88      0.93        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        14
#           17       1.00      0.96      0.98        23
#           18       1.00      0.87      0.93        23
#           19       1.00      1.00      1.00        23
#           20       0.93      0.68      0.79        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.96       440
#    macro avg       0.96      0.96      0.96       440
# weighted avg       0.97      0.96      0.96       440

# %%
print("Logistic Regression Classifier:")
print(classification_report(y_test, lr_pred))
# Out:
# Logistic Regression Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       0.85      0.85      0.85        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       0.94      1.00      0.97        17
#            6       0.80      0.94      0.86        17
#            7       1.00      1.00      1.00        14
#            8       0.87      0.87      0.87        23
#            9       1.00      1.00      1.00        20
#           10       0.77      0.91      0.83        11
#           11       0.94      0.81      0.87        21
#           12       1.00      1.00      1.00        19
#           13       0.91      0.88      0.89        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        14
#           17       0.92      0.96      0.94        23
#           18       1.00      0.91      0.95        23
#           19       1.00      1.00      1.00        23
#           20       0.89      0.84      0.86        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.95       440
#    macro avg       0.95      0.95      0.95       440
# weighted avg       0.95      0.95      0.95       440

# %%
import joblib 
file_name = 'crop_app'
joblib.dump(lr,'crop_app')
['crop_app']
# Out:
# ['crop_app']

# %%
app = joblib.load('crop_app')
arr = [[80,12,43,20.879744,72.002744,6.502985,72.935536]]

# %%
# Predict the class
predicted_class_index = app.predict(arr)

# Define the class names dictionary
class_names = {
    20: 'Rice', 11: 'Maize', 3: 'Chickpea', 9: 'Kidneybeans', 18: 'Pigeonpeas',
    13: 'Mothbeans', 14: 'Mungbean', 2: 'Blackgram', 10: 'Lentil', 19: 'Pomegranate',
    1: 'Banana', 12: 'Mango', 7: 'Grapes', 21: 'Watermelon', 15: 'Muskmelon',
    0: 'Apple', 16: 'Orange', 17: 'Papaya', 4: 'Coconut', 6: 'Cotton', 8: 'Jute',
    5: 'Coffee'
}

# Map the predicted class index to the class name
predicted_class = class_names[predicted_class_index[0]]

print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: Watermelon

# %%
import numpy as np

# Reshape the input data array to match the shape expected by the model
arr = np.array(arr)  # Convert to numpy array if it's not already
X_new = np.reshape(arr, (arr.shape[0], -1))  # Reshape to match input shape

# Make predictions
y_pred_proba = model.predict(X_new)
y_pred = np.argmax(y_pred_proba, axis=1)


# Define the class names dictionary
class_names = {
    20: 'Rice', 11: 'Maize', 3: 'Chickpea', 9: 'Kidneybeans', 18: 'Pigeonpeas',
    13: 'Mothbeans', 14: 'Mungbean', 2: 'Blackgram', 10: 'Lentil', 19: 'Pomegranate',
    1: 'Banana', 12: 'Mango', 7: 'Grapes', 21: 'Watermelon', 15: 'Muskmelon',
    0: 'Apple', 16: 'Orange', 17: 'Papaya', 4: 'Coconut', 6: 'Cotton', 8: 'Jute',
    5: 'Coffee'
}

# Map the predicted class index to the class name
predicted_class = class_names[y_pred[0]]

print("Predicted Class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Predicted Class: Watermelon

# %%
import joblib 
file_name = 'crop_app2'
joblib.dump(model,'crop_app2')
['crop_app2']
# Out:
# ['crop_app2']
